# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv("train_ready_dataset_v2.csv")

# %%
dataset.head()
# Out:
#   food_id           food_name     food_name_clean  calories_100g  \
# 0  FD0001                abon                abon          280.0
# 1  FD0002    abon ikan haruan    abon ikan haruan          513.0
# 2  FD0003           agar-agar           agar-agar            0.0
# 3  FD0004       alpukat segar       alpukat segar           85.0
# 4  FD0005  anggur hutan segar  anggur hutan segar           30.0
#
#    protein_100g  fat_100g  carbohydrate_100g  \
# 0           9.2      28.4                0.0
# 1          23.7      37.0               21.3
# 2           0.0       0.2                0.0
# 3           0.9       6.5                7.7
# 4           0.5       0.2                6.8
#
#                                            image_url  \
# 0  https://img-cdn.medkomtek.com/PbrY9X3ignQ8sVuj...
# 1  https://img-global.cpcdn.com/recipes/cbf330fbd...
# 2  https://res.cloudinary.com/dk0z4ums3/image/upl...
# 3  https://upload.wikimedia.org/wikipedia/commons...
# ...

# %%
dataset.to_excel("kentot.xlsx", index = False)
